# %%
import pandas as pd
from parser_new_cleaned import ctvc, fortune, keepcool, eusubstack, cleaning
companies = pd.read_csv("companies.csv")
deals = pd.read_csv("deals.csv")
companies.head()
# Out:
#             name                     domain        location  \
# 0        1kommas                        NaN         Germany
# 1       = «xfarm                        NaN           Italy
# 2       abatable  https://www.abatable.com/  United Kingdom
# 3  abbe-mobility                        NaN     Switzerland
# 4         accure                        NaN         Germany
#
#                                     tagline             investors
# 0               Solar panel system provider              ['g2vp']
# 1                      Superapp for farmers           ['partech']
# 2  Carbon procurement / market intelligence     ['azora capital']
# 3                     EV charging solutions           ['various']
# 4                Battery analytics software  ['incharge capital']

# %%
for row in companies.itertuples():
    if not isinstance(row.name,str):
        print(row)
# Out:
# Pandas(Index=8, name=nan, domain='https://monta.app/', location=nan, tagline=nan, investors='energize ventures')
